# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import spdiags
from scipy import sparse
from scipy.linalg import lstsq
import cv2

# %%
def LS_DEN(img,lam):
    y=img
    M=np.size(img,0)
    N=np.size(img,1)
    e = np.ones([M,1],dtype=int)
    e1 = np.ones([N,1],dtype=int)
    D = spdiags(np.transpose(np.column_stack((e,-2*e,e))),np.linspace(0,2,3),M,M)
    D1 = spdiags(np.transpose(np.column_stack((e1,-2*e1,e1))),np.linspace(0,2,3),N,N)
    F =sparse.eye(M).toarray() + lam*(np.transpose(D)@D)
    F1 =sparse.eye(N).toarray() + lam*(np.transpose(D1)@D1)
    x=np.linalg.solve(F,y)
    x1=np.linalg.solve(F,x.T)
    return x;

# %%
N=len(y)

# %%
x=np.linspace(1,500,500)
plt.plot(y)
plt.title("Clipped speevh waveform")
plt.xlabel('Time (samples)')
plt.ylim(-0.5,0.5)
# Out:
# (-0.5, 0.5)

# %%
e = np.ones([N,1],dtype=int)
from scipy.sparse import spdiags
D = spdiags(np.column_stack((e,-3*e,3*e,-e)),np.linspace(0,3,4),N-3,N)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25120\203975130.py in <module>
#       1 e = np.ones([N,1],dtype=int)
#       2 from scipy.sparse import spdiags
# ----> 3 D = spdiags(np.column_stack((e,-3*e,3*e,-e)),np.linspace(0,3,4),N-3,N)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\_construct.py in spdiags(data, diags, m, n, format)
#      67     elif n is None:
#      68         m, n = m
# ---> 69     return dia_matrix((data, diags), shape=(m, n)).asformat(format)
#      70
#      71
#
# ~\anaconda3\lib\site-packages\scipy\sparse\_dia.py in __init__(self, arg1, shape, dtype, copy)
#     149
#     150         if self.data.shape[0] != len(self.offsets):
# --> 151             raise ValueError('number of diagonals (%d) '
#     152                     'does not match the number of offsets (%d)'
# ...

# %%
D = spdiags(np.column_stack((e,-2*e,e)),np.linspace(0,2,3),204,204)
D1 = spdiags(np.column_stack((e1,-2*e1,e1)),np.linspace(0,2,3),204,204)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25120\3047554658.py in <module>
# ----> 1 D = spdiags(np.column_stack((e,-2*e,e)),np.linspace(0,2,3),204,204)
#       2 D1 = spdiags(np.column_stack((e1,-2*e1,e1)),np.linspace(0,2,3),204,204)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\_construct.py in spdiags(data, diags, m, n, format)
#      67     elif n is None:
#      68         m, n = m
# ---> 69     return dia_matrix((data, diags), shape=(m, n)).asformat(format)
#      70
#      71
#
# ~\anaconda3\lib\site-packages\scipy\sparse\_dia.py in __init__(self, arg1, shape, dtype, copy)
#     149
#     150         if self.data.shape[0] != len(self.offsets):
# --> 151             raise ValueError('number of diagonals (%d) '
#     152                     'does not match the number of offsets (%d)'
# ...

# %%
d= np.column_stack((e,-2*e,e))
c=[0,1,2]
D = spdiags(np.transpose(d),c,203,203)

# %%
F =sparse.eye(203).toarray() + 0.9*(np.transpose(D)@D)

# %%
path = r'D:\B_Tech_AIE\Semester_5\SIP\Week_9\2D_Image_Denoising_LS\Image_Smoothing\cameraman.jpeg'
img=cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img)

# %%
from skimage.util import random_noise
noise_img = random_noise(img, mode='gaussian',mean=0,var=0.005)
plt.imshow(noise_img)

# %%
lamda=0.9
yy1=LS_DEN(noise_img,lamda)

# %%
plt.imshow(yy1)
